# %%
# %matplotlib inline 
import math
import numpy as np
from matplotlib import pyplot as plt

# %%
im_orig = plt.imread('Wb_girl_warm.png')
plt.imshow(badimg)

# %%
satLevel = .01
q = [satLevel/2, 1-satLevel/2]

# %%
def flat(p):
    return p.reshape(-1, p.shape[-1])
imRGB_orig = flat(im_orig)*255;
empty_mario = np.zeros((1456, 2189, 4))
