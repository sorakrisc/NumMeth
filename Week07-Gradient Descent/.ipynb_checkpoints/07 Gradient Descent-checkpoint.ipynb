# %%
# %matplotlib inline
import numpy as np
import math
from matplotlib import pyplot as plt

# %% [markdown]
# ##1D Gradient Descent

# %% [markdown]
# 1) Let us consider the function
# $$ f(x) = (x-2)^2 + 1 $$
# First plot it.

# %%
def f(x):
    return (x-2)**2 + 1

xs = np.linspace(0,5,100)
ys =[f(x) for x in xs]
plt.plot(xs, ys)

# %% [markdown]
# 2) If we start at $x=4$, which way should we move and why?

# %% [markdown]
# Slope is negative(-) : Increase guess
#
# Slope is positive(+) : Decrease guess
#
# $ x_{n+1} = x_n - stepsize \times  \frac{f'(x_n)}{|f'(x_n)|} $
#
# stepsize how far you should go
#
# fraction is the direction you should go
#
# $ x_{n+1} $ is gradient descent

# %% [markdown]
# 3)If the step size is constants = 1.1, what does the update rule look like?
#
# $$x_{n+1} = \ldots$$
#
# start at 4

# %% [markdown]
# $$ x_{n+1} = x_n - 1.1 \times \frac{2(x_n-2)}{|2(x_n-2)|}$$

# %% [markdown]
# 4)Let try it with step size = 1.1. For 10 iteration. Print and plot your point as you go. Can you understand the behavior?

# %%
def fp(x):
    return 2*(x-2)
def gradDesc(xn, ss, fp ,k):
    if(k ==0):
        return xn
    else:
        plt.plot(xn, f(xn), "o")
        return gradDesc(xn-ss*fp(xn)/ abs(fp(xn)), ss, fp, k-1)
    
print("ANS:" ,gradDesc(4,1.1,fp,10 ))

xs = np.linspace(0,5,100)
ys =[f(x) for x in xs]
plt.plot(xs, ys)
plt.grid()
# Out:
# ANS: 1.7999999999999998

# %% [markdown]
# 5)Now let's try step size=0.01 for 100 iteration. Print and plot your point as you go. Can you understand the behavior?

# %%
print("ANS:" ,gradDesc(4,0.01,fp,100 ))

xs = np.linspace(0,5,100)
ys =[f(x) for x in xs]
plt.plot(xs, ys)
plt.grid()
# Out:
# ANS: 3.0000000000000213

# %% [markdown]
# 6) When do we want the step size to be small and when do you want the step size to be big?

# %% [markdown]
# big when it don't the minimum yet
#
# small when you went to the other side

# %% [markdown]
# AJ ANS:
# 1. The step size should be small when we are near the minimum so that we get an accurate answer.
# 2. The step size should be large when we are far away from the minimum so that we get to the minimum quickly.

# %% [markdown]
# 7) What function kind of does that?

# %% [markdown]
# $ x_{n+1} = x_n - \lambda \left| f'(x_n) \right| \times  \frac{f'(x_n)}{\left|f'(x_n) \right|} $
#
# $ x_{n+1} = x_n - \lambda f'(x_n) $

# %% [markdown]
# 8)If we use that function, what does the update rule looks like.

# %%
def fp(x):
    return 2*(x-2)
def gradDescBetter(xn, lr, fp ,k):
    if(k ==0):
        plt.plot(xn, f(xn), "o")
        return xn
    else:
        plt.plot(xn, f(xn), "o")
        return gradDescBetter(xn-lr*fp(xn), lr, fp, k-1)

# %% [markdown]
# 9) Try it with $\lambda=0.1$. Print and Plot to see what happens?

# %%
print("ANS:" ,gradDescBetter(4,0.1,fp,10 ))

xs = np.linspace(0,5,100)
ys =[f(x) for x in xs]
plt.plot(xs, ys)
plt.grid()
# Out:
# ANS: 2.2147483647999997

# %% [markdown]
# 10) Try it with $\lambda = 1.1$. For 4 iterations. Can you see how it goes?

# %%
def f(x):
    return (x-2)**2 + 1
def fp(x):
    return 2*(x-2)
def gradDescBetter(xn, lr, fp ,k):
    if(k==0):
        plt.plot(xn, f(xn), "o")
        return xn
    else:
        plt.plot(xn, f(xn), "o")
        return gradDescBetter(xn-lr*fp(xn), lr, fp, k-1)

print("ANS:" ,gradDescBetter(4,1.1,fp,4 ))

xs = np.linspace(0,5,100)
ys =[f(x) for x in xs]
plt.plot(xs, ys)
plt.grid()
# Out:
# ANS: 6.147200000000002

# %% [markdown]
# if it doesn't conver lambda too large
# else too small

# %% [markdown]
# ###Multi-Dimension Gradient Descent

# %% [markdown]
# 1) Let us consider the function.
# $$f(x,y) = (x-2)^2 + xy + 2y + 1$$
# Make the 3D plot.

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
#see matplotlib3d surface
def f(x,y):
    return (x-2)**2+x*y+y**2+1
nx = 200
ny = 200
x = np.linspace(-20,20,nx)
y = np.linspace(-20,20,ny)
xgrid, ygrid = np.meshgrid(x, y)
#print ygrid
uz = np.zeros((nx,ny))
for ix in range(nx):
    for iy in range(ny):
        xx = x[ix]
        yy = y[iy]
        uz[iy,ix] = f(xx,yy) ##<<<<<<This is not a typo: [iy,ix]
        
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
plt.gca().view_init(elev=15., azim=30)
ucs = ax.plot_surface(xgrid, ygrid, uz, cmap=cm.coolwarm)
plt.title('f(x,y)')

# %% [markdown]
# 2) Plot the contour.

# %%
#see http://matplotlib.org/examples/pylab_examples/contour_demo.html
def f(x,y):
    return (x-2)**2+x*y+y**2+1

nx = 200
ny = 200
x = np.linspace(-20,20,nx)
y = np.linspace(-20,20,ny)
xgrid, ygrid = np.meshgrid(x, y)
#print ygrid
uz = np.zeros((nx,ny))

for ix in range(nx):
    for iy in range(ny):
        xx = x[ix]
        yy = y[iy]
        uz[iy,ix] = f(xx,yy) ##<<<<<<This is not a typo: [iy,ix]

ucs = plt.contour(x, y, uz, [2,10,50,100,200,400,500], cmap=cm.brg)
plt.clabel(ucs, inline=1, fontsize=10)
plt.grid()
plt.title('f(x,y)')

def gradf(xn):
    one =2*(xn[0]-2)+xn[1]
    two = xn[0]+2*xn[1]
    return np.array([one, two])
def ultimateGradDesc(xn,lamb,k):
    plt.plot(xn[0],xn[1], "o")
    if (k==0):
        return xn
    else:
        return ultimateGradDesc(xn - lamb *gradf(xn) ,lamb,k-1)
    
ultimateGradDesc(np.array([10,-15]),0.1,100)
# Out:
# array([ 2.66694556, -1.33361223])

# %% [markdown]
# 3)Where do you think the minimum is?

# %% [markdown]
# In the center of the smallest oval

# %% [markdown]
# 4)What is the gradient at (10,-15)? Use plt.arrow to plot arrow.

# %%
plt.arrow(0,0,1,1,head_width=0.1, head_length=0.1,fc='k',ec='k')
plt.xlim(0,2)
plt.ylim(0,2)
# Out:
# (0, 2)

# %% [markdown]
# 5) If we want to minimize the function which way should we go? Find the unit vector in that direction.

# %% [markdown]
# 6) What should your update rule look like? Use vector addition.

# %% [markdown]
# 7) Use what we learn in 1D. How far should we go? What should the update rule really look like?

# %% [markdown]
# 8) Use $\lambda = 0.1$ and see where the points go

# %%
#see http://matplotlib.org/examples/pylab_examples/contour_demo.html
def f(x,y):
    return (x-2)**2+x*y+y**2+1

nx = 200
ny = 200
x = np.linspace(-20,20,nx)
y = np.linspace(-20,20,ny)
xgrid, ygrid = np.meshgrid(x, y)
#print ygrid
uz = np.zeros((nx,ny))

for ix in range(nx):
    for iy in range(ny):
        xx = x[ix]
        yy = y[iy]
        uz[iy,ix] = f(xx,yy) ##<<<<<<This is not a typo: [iy,ix]

ucs = plt.contour(x, y, uz, [2,10,50,100,200,400,500], cmap=cm.brg)
plt.clabel(ucs, inline=1, fontsize=10)
plt.grid()
plt.title('f(x,y)')

def gradf(xn):
    one =2*(xn[0]-2)+xn[1]
    two = xn[0]+2*xn[1]
    return np.array([one, two])
def ultimateGradDesc(xn,lamb,k):
    plt.plot(xn[0],xn[1], "o")
    if (k==0):
        return xn
    else:
        return ultimateGradDesc(xn - lamb *gradf(xn) ,lamb,k-1)
    
ultimateGradDesc(np.array([10,-15]),0.1,100)
# Out:
# array([ 2.66694556, -1.33361223])

# %% [markdown]
# ###Linear Regression Revisited

# %% [markdown]
# Let us consider the problem of findind a line that pass through the points.

# %%
np.random.seed(123)
n = 100
x = np.linspace(0,1,n)
y = -2*x + 1 + np.random.randn(n)/2
plt.plot(x,y,'.r')

# %% [markdown]
# 1) What exactly are we trying to minimize and why?

# %% [markdown]
# 2) Minimize and Visualize it.

# %% [markdown]
# ###Separating Line.

# %% [markdown]
# We want to draw a separating line betwen two datasets shown below.

# %%
np.random.seed(234)
n1 = 100
n2 = 100
mean = [0, 0]
cov = [[1, -0.5], [-0.5, 1]]
r1, r2 = np.random.multivariate_normal(mean, cov, n1).T
#plt.plot(r1, r2, '.r')

mean = [2, 2]
cov = [[1, 0], [0, 1]]
b1, b2 = np.random.multivariate_normal(mean, cov, n2).T
#plt.plot(b1, b2, '.b')

c = np.zeros(n1+n2)
c[:n1] = 1.
c[n1:] = 0.
#print c

d = np.zeros((n1+n2,2))
d[:n1,0] = r1
d[:n1,1] = r2
d[n1:,0] = b1
d[n1:,1] = b2

# %%
plt.plot(d[c==1,0], d[c==1,1],'.r')#note boolean indexing
plt.plot(d[c==0,0], d[c==0,1],'.b')#note boolean indexing

# %% [markdown]
# 1) How can we model this as a optimization problem?

# %%
def  cost(w):
    a,b = w
    ans = 0
    for dd, cc in zip(d, c):
        x, y = dd
        if cc> 0.5: #red
            if y<(a*x+b):
                pass
            else:
                ans+=(y-a*x+b)
            
        else: #blue
            if y<(a*x+b):
                ans+=-(y -a*x +b)
            else:
                pass
    return ans
print (cost(np.array([1,1])))
# Out:
# 64.757491579

# %%
import scipy
from scipy.optimize import minimize
minimize(cost,[0,0])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3c5e4a453977> in <module>()
# ----> 1 import scipy
#       2 from scipy.optimize import minimize
#       3 minimize(cost,[0,0])
#
# ModuleNotFoundError: No module named 'scipy'

# %% [markdown]
# 2) What equation do we plot?

# %% [markdown]
# 3) Minimize and plot it to see that you get the right line.

# %%
#this is how you make a padded array
nr, nc = d.shape
pd = np.zeros((nr,nc+1))
pd[:,1:] = d
pd[:,0] =  1.0
print pd[:20]
# Out:
# [[ 1.         -1.23086966  0.18731902]
#  [ 1.          0.15690022  0.76467807]
#  [ 1.         -1.48876741 -1.64011723]
#  [ 1.          1.30714602 -0.37248023]
#  [ 1.          0.67461839  0.75059711]
#  [ 1.          0.94584269 -0.01901824]
#  [ 1.          1.65971858 -0.56346172]
#  [ 1.          1.91304992 -1.43409072]
#  [ 1.         -1.25215912  1.07673845]
#  [ 1.         -0.37260327 -0.51585145]
#  [ 1.          0.71465901  0.19371616]
#  [ 1.         -0.10270834 -1.22090529]
#  [ 1.         -1.30358744  1.60276889]
#  [ 1.          0.42723536  0.61684556]
#  [ 1.         -0.2558605   0.00338542]
#  [ 1.         -0.48066857  0.98644225]
#  [ 1.         -0.2691181   0.41096303]
#  [ 1.          1.3099536  -0.67015697]
#  [ 1.          0.28005885 -0.74420921]
#  [ 1.          1.34634767 -0.03558485]]
